# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import xlsxwriter

train = pd.read_excel('train.xlsx')
train_y=train.SalePrice
train.dtype='float128'
predictor_cols=['OverallQual','GrLivArea']#相関係数0.7以上
train_X=train[predictor_cols]
forest_model=RandomForestRegressor()
forest_model.fit(train_X,train_y)
test = pd.read_excel('test.xlsx')
test.dtype='float128'
test_X=test[predictor_cols]
predicted_prices=forest_model.predict(test_X)
print(predicted_prices)
df = pd.DataFrame(predicted_prices)
df.to_csv("price.csv")
# Out:
# [130641.88568376 149615.         156550.         ... 139315.9
#  131050.         250853.        ]

# %%
df
# Out:
#                   0
# 0     131396.214286
# 1     155970.000000
# 2     153150.000000
# 3     175115.000000
# 4     232250.000000
# 5     191300.000000
# 6     148778.333333
# 7     144200.000000
# 8     186000.200000
# 9     102110.000000
# 10    185530.000000
# 11     99390.726190
# 12    143820.000000
# 13    162386.263889
# 14    138220.000000
# 15    430215.100000
# 16    221900.000000
# 17    334188.200000
# 18    310550.000000
# 19    432882.700000
# 20    289233.333333
# 21    199500.000000
# 22    155799.000000
# 23    164100.000000
# 24    216206.250000
# 25    221500.000000
# 26    317121.300000
# 27    248000.000000
# 28    171906.666667
# 29    151800.000000
# ...             ...
# 1429   80651.011905
# 1430  181950.000000
# 1431   56481.100000
# 1432  151980.000000
# 1433   79700.000000
# 1434  275470.400000
# 1435  275470.143333
# 1436  164420.000000
# 1437  165789.333333
# 1438  247560.000000
# 1439  164116.666667
# 1440  175150.000000
# 1441  138857.500000
# ...

# %%
predicted_prices.shape
# Out:
# (1459,)

# %%
train_y.shape
# Out:
# (1460,)

# %%
#相関係数0.4以上
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import xlsxwriter

train = pd.read_excel('train.xlsx')
train_y=train.SalePrice
train.dtype='float128'
np.isnan(train.values.any())
predictor_cols=['OverallQual','GrLivArea','GarageCars','TotalBsmtSF','GarageArea','1stFlrSF','FullBath','TotRmsAbvGrd','YearBuilt','YearRemodAdd','Fireplaces']#相関係数0.7以上’GarageYrBlt、MasVnrArea、
train_X=train[predictor_cols]
forest_model=RandomForestRegressor()
forest_model.fit(train_X,train_y)
test = pd.read_excel('test.xlsx')
test_X=test[predictor_cols]

np.isnan(test_X.values.any())

test.dtype='float128'
predicted_prices=forest_model.predict(test_X)
np.isnan(predicted_prices.values.any())
np.isfinite(mat.all())

df = pd.DataFrame(predicted_prices)
df.to_csv("price2.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4134abb93d93> in <module>()
#      20
#      21 test.dtype='float128'
# ---> 22 predicted_prices=forest_model.predict(test_X)
#      23 np.isnan(predicted_prices.values.any())
#      24 np.isfinite(mat.all())
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict(self, X)
#     679         check_is_fitted(self, 'estimators_')
#     680         # Check data
# --> 681         X = self._validate_X_predict(X)
#     682
#     683         # Assign chunk of trees to jobs
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _validate_X_predict(self, X)
#     355                                  "call `fit` before exploiting the model.")
#     356
# --> 357         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     358
#     359     @property
#
# ...

# %%
train_X.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-9f908580d7d4> in <module>()
# ----> 1 train_X.dtype
#
# c:\users\ishin\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
my_submission=pd.DataFrame({'ID': test.Id, 'SalePrice': predicted_prices})
my_submission.to_csv('submission.csv',index=False)

# %%
import pandas as pd
import xlsxwriter
df=pd.write_xlsx('test.xlsx', sheet_name='SaleP')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-536c34e2a608> in <module>()
#       1 import pandas as pd
#       2 import xlsxwriter
# ----> 3 df=pd.write_xlsx('test.xlsx', sheet_name='SaleP')
#
# AttributeError: module 'pandas' has no attribute 'write_xlsx'

# %%
def f():
    print("test")

# %%
f()
# Out:
# test

# %%
RandomForestRegressor?

# %%
predictor_cols=['OverallQual','GrLivArea','GarageCars','TotalBsmtSF','GarageArea','1stFlrSF','FullBath','TotRmsAbvGrd','YearBuilt'\
                ,'YearRemodAdd','GarageYrBlt','MasVnrArea','Fireplaces']

# %%
#相関係数0.4以上
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import xlsxwriter
model = RandomForestRegressor(n_estimators=500, oob_score=True, random_state=42)
predictor_cols=['OverallQual','GrLivArea','GarageCars','TotalBsmtSF','GarageArea','1stFlrSF','FullBath','TotRmsAbvGrd','YearBuilt','YearRemodAdd','Fireplaces']#相関係数0.7以上
train_X=train[predictor_cols]
model.fit(X_train, y_train)
test_X=test[predictor_cols]
pre2= model.predict(X_test)
pre2
